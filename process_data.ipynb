# %%
import numpy as np # linear algebra
import pandas as pandas
import os as os2

# %%
# df_raw = pd.read_csv('transjakarta_gps.csv')

# %%
# df_raw = df_raw.drop(columns=['location', 'dtd', 'corridor', 'course', 'color'])

# %%
df_raw['gps_datetime'].head(10)
# Out:
# 0    2019-11-26 14:00:29
# 1    2019-11-26 14:00:54
# 2    2019-11-26 14:01:29
# 3    2019-11-26 14:01:59
# 4    2019-11-26 14:02:29
# 5    2019-11-26 14:02:59
# 6    2019-11-26 14:03:29
# 7    2019-11-26 14:03:59
# 8    2019-11-26 14:04:29
# 9    2019-11-26 14:04:59
# Name: gps_datetime, dtype: object

# %%
df_raw = df_raw.sort_values(by='gps_datetime',ascending=True)

# %%
df_raw.head(10)
# Out:
#          bus_code  trip_id         gps_datetime   longitude  latitude  speed
# 155080  MYS 17043    6.001  2019-11-26 14:00:00  106.818498 -6.305415    6.6
# 625326    TJ 0517  12.K001  2019-11-26 14:00:00  106.830500 -6.135078    0.0
# 125840    MB 1624   5.C030  2019-11-26 14:00:00  106.872277 -6.288803    2.3
# 125387    MB 1623    2.001  2019-11-26 14:00:00  106.899220 -6.178257   44.2
# 124934    MB 1622    3.010  2019-11-26 14:00:00  106.721487 -6.152882   38.2
# 371260   PPD 0430  B11.395  2019-11-26 14:00:00  106.879128 -6.245070    0.0
# 124029    MB 1620    2.101  2019-11-26 14:00:00  106.899907 -6.193213    0.0
# 123167    MB 1618    3.011  2019-11-26 14:00:00  106.705807 -6.154113    0.0
# 122261    MB 1616    2.101  2019-11-26 14:00:00  106.899680 -6.193102    0.0
# 704044    TJ 0780  GR1.100  2019-11-26 14:00:00  106.822992 -6.185553    2.0

# %%
df_raw.to_csv('processed_jakarta_gps.csv', index=False)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 775458 entries, 155080 to 755511
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   bus_code      775458 non-null  object
#  1   trip_id       773791 non-null  object
#  2   gps_datetime  775458 non-null  object
#  3   longitude     775458 non-null  float64
#  4   latitude      775458 non-null  float64
#  5   speed         775458 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 41.4+ MB

# %%
print(len(df_raw))
# Out:
# 775458

# %%
df_raw.to_numpy().tolist()
# Out:
# [['MYS 17043', '6.001', '2019-11-26 14:00:00', 106.818498, -6.305415, 6.6],
#  ['TJ 0517', '12.K001', '2019-11-26 14:00:00', 106.8305, -6.135078, 0.0],
#  ['MB 1624', '5.C030', '2019-11-26 14:00:00', 106.872277, -6.288803, 2.3],
#  ['MB 1623', '2.001', '2019-11-26 14:00:00', 106.89922, -6.178257, 44.2],
#  ['MB 1622', '3.010', '2019-11-26 14:00:00', 106.721487, -6.152882, 38.2],
#  ['PPD 0430', 'B11.395', '2019-11-26 14:00:00', 106.879128, -6.24507, 0.0],
#  ['MB 1620', '2.101', '2019-11-26 14:00:00', 106.899907, -6.193213, 0.0],
#  ['MB 1618', '3.011', '2019-11-26 14:00:00', 106.705807, -6.154113, 0.0],
#  ['MB 1616', '2.101', '2019-11-26 14:00:00', 106.89968, -6.193102, 0.0],
#  ['TJ 0780', 'GR1.100', '2019-11-26 14:00:00', 106.822992, -6.185553, 2.0],
#  ['MB 1612', '2.101', '2019-11-26 14:00:00', 106.899607, -6.193093, 0.0],
#  ['MB 1611', '2.101', '2019-11-26 14:00:00', 106.899475, -6.193145, 0.0],
#  ['TJW 10025', '8.202', '2019-11-26 14:00:00', 106.831482, -6.16776, 21.0],
# ...
